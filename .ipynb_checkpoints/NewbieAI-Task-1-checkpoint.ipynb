# %% [markdown]
# TASK-1: Data Cleaning, find count of missing values in each column, describe the dataset (mean,median etc ).

# %%
# importing libraries
import numpy as np
import pandas as pd
import seaborn as sns
import os

# %%
# url = "https://docs.google.com/spreadsheets/d/1GcYSfR0ox26Tc-7-8AhLA3Pgx2X1o9IKK-WDL5rDNa4/edit#gid=1426969578"
data = pd.read_csv('train - train (2).csv')
data.head()
# Out:
#    Unnamed: 0    year  month  day  hour  PM2.5  temperature pressure  rain  \
# 0           0    2013  -37.0  1.0   0.0    4.0         -0.7   102-37   0.0
# 1           1  201-37  -37.0  1.0   1.0    8.0         -1.1   1023.2   0.0
# 2           2    2013    3.0  1.0   2.0    7.0         -1.1   1023.5   0.0
# 3           3    2013    3.0  1.0   3.0    6.0         -1.4   1024.5   0.0
# 4           4    2013    3.0  1.0   4.0    3.0         -2.0   1025.2   0.0
#
#   wind_direction  wind_speed
# 0            NNW         4.4
# 1              N         NaN
# 2            NNW         5.6
# 3             NW         3.1
# 4              N         2.0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31527 entries, 0 to 31526
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      31527 non-null  int64
#  1   year            31512 non-null  object
#  2   month           31521 non-null  float64
#  3   day             31507 non-null  float64
#  4   hour            31519 non-null  float64
#  5   PM2.5           31513 non-null  float64
#  6   temperature     31508 non-null  float64
#  7   pressure        31500 non-null  object
#  8   rain            31515 non-null  float64
#  9   wind_direction  31467 non-null  object
#  10  wind_speed      31502 non-null  float64
# dtypes: float64(7), int64(1), object(3)
# memory usage: 2.6+ MB

# %%
data.shape
# Out:
# (31527, 11)

# %%
# data['year'] = data['year'].astype(float)

# %%
# get the number of missing data points per column
data.isnull().sum()
# Out:
# Unnamed: 0         0
# year              15
# month              6
# day               20
# hour               8
# PM2.5             14
# temperature       19
# pressure          27
# rain              12
# wind_direction    60
# wind_speed        25
# dtype: int64

# %%
# sns.heatmap(data.isnull(), yticklabels=False, annot=True)

# %%
newdata = data

# %%
newdata.drop("Unnamed: 0", axis = 1, inplace=True)
newdata
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:4163: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#        year  month   day  hour  PM2.5  temperature pressure  rain  \
# 0      2013  -37.0   1.0   0.0    4.0         -0.7   102-37   0.0
# 2      2013    3.0   1.0   2.0    7.0         -1.1   1023.5   0.0
# 3      2013    3.0   1.0   3.0    6.0         -1.4   1024.5   0.0
# 4      2013    3.0   1.0   4.0    3.0         -2.0   1025.2   0.0
# 6      2013    3.0   1.0   6.0    3.0         -2.6   1026.5   0.0
# ...     ...    ...   ...   ...    ...          ...      ...   ...
# 31522  2017    2.0  27.0   6.0   80.0         -0.3   1019.4   0.0
# 31523  2017    2.0  27.0  16.0   75.0         15.9     1014   0.0
# 31524  2017    2.0  27.0  19.0   51.0         11.5   1014.1   0.0
# 31525  2017    2.0  28.0   2.0    9.0          8.6     1016   0.0
# 31526  2017    2.0  28.0  14.0    5.0         14.6   1013.3   0.0
#
#       wind_direction  wind_speed
# 0                NNW         4.4
# 2                NNW         5.6
# 3                 NW         3.1
# 4                  N         2.0
# 6                NNE         2.5
# ...              ...         ...
# 31522            ENE         0.8
# 31523             SW         2.9
# 31524            SSW         1.0
# 31525            NNE         0.9
# 31526              N         3.6
#
# [31371 rows x 10 columns]

# %%
newdata.fillna(method='ffill')
# Out:
#        Unnamed: 0    year  month   day  hour  PM2.5  temperature pressure  \
# 0               0    2013  -37.0   1.0   0.0    4.0         -0.7   102-37
# 1               1  201-37  -37.0   1.0   1.0    8.0         -1.1   1023.2
# 2               2    2013    3.0   1.0   2.0    7.0         -1.1   1023.5
# 3               3    2013    3.0   1.0   3.0    6.0         -1.4   1024.5
# 4               4    2013    3.0   1.0   4.0    3.0         -2.0   1025.2
# ...           ...     ...    ...   ...   ...    ...          ...      ...
# 31522       35022    2017    2.0  27.0   6.0   80.0         -0.3   1019.4
# 31523       35032    2017    2.0  27.0  16.0   75.0         15.9     1014
# 31524       35035    2017    2.0  27.0  19.0   51.0         11.5   1014.1
# 31525       35042    2017    2.0  28.0   2.0    9.0          8.6     1016
# 31526       35054    2017    2.0  28.0  14.0    5.0         14.6   1013.3
#
#        rain wind_direction  wind_speed
# 0       0.0            NNW         4.4
# 1       0.0              N         4.4
# 2       0.0            NNW         5.6
# 3       0.0             NW         3.1
# 4       0.0              N         2.0
# ...     ...            ...         ...
# 31522   0.0            ENE         0.8
# 31523   0.0             SW         2.9
# 31524   0.0            SSW         1.0
# 31525   0.0            NNE         0.9
# 31526   0.0              N         3.6
#
# [31527 rows x 11 columns]

# %%
newdata.interpolate()
# Out:
#        Unnamed: 0    year  month   day  hour  PM2.5  temperature pressure  \
# 0               0    2013  -37.0   1.0   0.0    4.0         -0.7   102-37
# 1               1  201-37  -37.0   1.0   1.0    8.0         -1.1   1023.2
# 2               2    2013    3.0   1.0   2.0    7.0         -1.1   1023.5
# 3               3    2013    3.0   1.0   3.0    6.0         -1.4   1024.5
# 4               4    2013    3.0   1.0   4.0    3.0         -2.0   1025.2
# ...           ...     ...    ...   ...   ...    ...          ...      ...
# 31522       35022    2017    2.0  27.0   6.0   80.0         -0.3   1019.4
# 31523       35032    2017    2.0  27.0  16.0   75.0         15.9     1014
# 31524       35035    2017    2.0  27.0  19.0   51.0         11.5   1014.1
# 31525       35042    2017    2.0  28.0   2.0    9.0          8.6     1016
# 31526       35054    2017    2.0  28.0  14.0    5.0         14.6   1013.3
#
#        rain wind_direction  wind_speed
# 0       0.0            NNW         4.4
# 1       0.0              N         5.0
# 2       0.0            NNW         5.6
# 3       0.0             NW         3.1
# 4       0.0              N         2.0
# ...     ...            ...         ...
# 31522   0.0            ENE         0.8
# 31523   0.0             SW         2.9
# 31524   0.0            SSW         1.0
# 31525   0.0            NNE         0.9
# 31526   0.0              N         3.6
#
# [31527 rows x 11 columns]

# %%
newdata.isnull().sum()
# Out:
# year              0
# month             0
# day               0
# hour              0
# PM2.5             0
# temperature       0
# pressure          0
# rain              0
# wind_direction    0
# wind_speed        0
# dtype: int64

# %%
# remove all the rows that contain a missing value
# newdata = data.dropna()

# %%
# remove all columns with atleast one missing value
# columns_with_na_dropped = newdata.dropna(axis=1)
# columns_with_na_dropped.head()
# Out:
#    Unnamed: 0  year  month  day  hour  PM2.5  temperature pressure  rain  \
# 0           0  2013  -37.0  1.0   0.0    4.0         -0.7   102-37   0.0
# 2           2  2013    3.0  1.0   2.0    7.0         -1.1   1023.5   0.0
# 3           3  2013    3.0  1.0   3.0    6.0         -1.4   1024.5   0.0
# 4           4  2013    3.0  1.0   4.0    3.0         -2.0   1025.2   0.0
# 6           6  2013    3.0  1.0   6.0    3.0         -2.6   1026.5   0.0
#
#   wind_direction  wind_speed
# 0            NNW         4.4
# 2            NNW         5.6
# 3             NW         3.1
# 4              N         2.0
# 6            NNE         2.5

# %%
# just how much data did we lose?
# print("Columns in original dataset: %d \n" % newdata.shape[1])
# print("Columns with na's dropped: %d" % columns_with_na_dropped.shape[1])
# Out:
# Columns in original dataset: 11
#
# Columns with na's dropped: 11

# %%
newdata.describe()
# Out:
#          Unnamed: 0         month           day          hour         PM2.5  \
# count  31371.000000  31371.000000  31371.000000  31371.000000  3.137100e+04
# mean   16178.610755      6.458481     15.419368     11.290396  2.104622e+03
# std     9502.039336      3.315128     33.205253     37.211471  3.583169e+05
# min        0.000000    -37.000000  -5656.000000  -6464.000000  3.000000e+00
# 25%     7885.500000      4.000000      8.000000      5.000000  2.300000e+01
# 50%    16257.000000      6.000000     15.000000     11.000000  5.800000e+01
# 75%    24324.500000      9.000000     23.000000     18.000000  1.120000e+02
# max    35054.000000     12.000000     31.000000     23.000000  6.346466e+07
#
#         temperature          rain    wind_speed
# count  31371.000000  31371.000000  31371.000000
# mean      14.387083      0.072070      1.697453
# std       11.293124      0.951885      1.337735
# min      -16.800000      0.000000    -79.000000
# 25%        4.400000      0.000000      0.900000
# 50%       15.900000      0.000000      1.400000
# 75%       23.700000      0.000000      2.200000
# max       40.500000     72.500000     11.200000

# %%
# identifying the outliers
# sns.boxplot(x='month', data=newdata)
# Out:
# <AxesSubplot:xlabel='month'>
